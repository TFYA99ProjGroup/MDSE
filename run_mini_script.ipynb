# %%
# Add scripts folder to sys.path if needed
from mini_script import generateTestCrystal
from ase.visualize import view

# Create a crystal and render inline
crystal = generateTestCrystal()
view(crystal, viewer='ngl')
